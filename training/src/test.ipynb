# %%
import matplotlib.pyplot as plt
import numpy as np

def plot_(epoch, loss_train,loss_eval):
    n_ep= np.arange(epoch)+1
    plt.plot(n_ep,loss_train)
    plt.plot(n_ep,loss_eval)
    plt.xlabel("Epoch")
    plt.ylabel("loss")
    plt.legend(["loss_train","loss_eval"])
    plt.show()
loss_train=[ 0.2256 ,0.0605 , 0.0482 , 0.0424,0.0384 , 0.0360 , 0.0340 , 0.0321 , 0.0307, 0.0297]
loss_eval= [ 0.0540,0.0370,0.0307, 0.0282,0.0266,0.0245,0.0240, 0.0236, 0.0223, 0.0222]
plot_(10,loss_train,loss_eval)

# %%
loss_train=[0.1995,0.0537 ,0.0416 , 0.0364 ,0.0331, 0.0303 , 0.0287, 0.0277 , 0.0269 , 0.0260]

loss_eval= [ 0.0640,0.0491,0.0416,0.0373,0.0345, 0.0326,0.0325,0.0324,0.0324, 0.0311]
plot_(10,loss_train,loss_eval)

# %%
import json

# Chemin du fichier
file_path = "/Users/vanessaguerrier/Downloads/projet_TER_M2/data/all_articles.json"

# --- 1. Lire le fichier ---
with open(file_path, 'r', encoding='utf-8') as fichier:
    datas = json.load(fichier)

# --- 2. Ajouter le numéro d'article ---
for i, article in enumerate(datas):
    article["metadata"]["article_number"] = i + 1

# --- 3. Réécrire dans le même fichier ---
with open( "/Users/vanessaguerrier/Downloads/projet_TER_M2/data/all_articles.json", 'w', encoding='utf-8') as fichier:
    json.dump(datas, fichier, ensure_ascii=False, indent=4)

# %%
import os 
from preparation_data_train import *
def lire_et_nettoyage_file_():
    for i in range(113):
        file_name= f"/Users/vanessaguerrier/Downloads/projet_TER_M2/data/GreenMIR/texts/article_{i+1}.txt"
        with open(file_name,"r",encoding="utf-8")as f:
            contenu = f.read()
        f.close()
        text= remove_references(contenu)
        with open( f"/Users/vanessaguerrier/Downloads/projet_TER_M2/data/GreenMIR/text_nettoyer/article{i+1}.txt", 'w', encoding='utf-8') as f:
            f.write(text)
        f.close()
lire_et_nettoyage_file_()

# %%
import numpy as np
li=np.array([2,2,2,3,4,44,5,5,5])
np.unique(li)
la= [2,2,2,3,4,44,5,5,5]
la.index(5)
# Out:
# 6
